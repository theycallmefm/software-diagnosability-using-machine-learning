# %%
from pandas import DataFrame, read_csv
import pandas as pd

# %%
Location = r'/Users/handekaratay/Desktop/Datas/Lang/lang_1_buggy.csv'
result = pd.read_csv(Location)
for i in range(2,66):
    Location=r'/Users/handekaratay/Desktop/Datas/Lang/lang_'+str(i)+'_buggy.csv'
    df = pd.read_csv(Location)
    result = pd.concat([result, df], axis=1)

file_name="lang_results.csv"
result = result.T
result = result [['Abstractness','Average Block Depth', 'Average Cyclomatic Complexity', 'Average Number of Methods Per Type', 'Efferent Couplings', 'Lines of Code', 'Number of Methods', 'Number of Packages', 'Weighted Methods']]
result.to_csv(file_name, encoding='utf-8', index=False)
result
# Out:
#                                                    Abstractness  \
# Metric results for lang_1_buggy at 6/7/18 10:21 AM         8.6%
# Metric results for lang_2_buggy at 6/7/18 10:23 AM         8.6%
# Metric results for lang_3_buggy at 6/7/18 10:23 AM         8.6%
# Metric results for lang_4_buggy at 6/7/18 10:24 AM         8.6%
# Metric results for lang_5_buggy at 6/7/18 10:25 AM         8.6%
# Metric results for lang_6_buggy at 6/7/18 10:26 AM         8.7%
# Metric results for lang_7_buggy at 6/7/18 10:26 AM         8.7%
# Metric results for lang_8_buggy at 6/7/18 10:27 AM         8.7%
# Metric results for lang_9_buggy at 6/7/18 10:28 AM         8.7%
# Metric results for lang_10_buggy at 6/7/18 10:2...         8.7%
# Metric results for lang_11_buggy at 6/7/18 10:3...         8.7%
# Metric results for lang_11_buggy at 6/7/18 10:3...         8.7%
# Metric results for lang_13_buggy at 6/7/18 10:3...         8.7%
# Metric results for lang_14_buggy at 6/7/18 10:3...         8.4%
# ...
